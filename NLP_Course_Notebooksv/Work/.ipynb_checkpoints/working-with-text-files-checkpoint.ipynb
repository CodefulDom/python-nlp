# %% [markdown]
# ## Working with Text Files - Part One

# %%
person = 'Dom'

# %%
print('My name is {}'.format(person))
# Out:
# My name is Dom

# %%
print(f'My name is {person} and I love python!')
# Out:
# My name is Dom and I love python!

# %%
d = {'a':123, 'b':456}

# %%
d
# Out:
# {'a': 123, 'b': 456}

# %%
my_list = [0,1,2]

# %%
print(f'My favorite number is {my_list[0]}')
# Out:
# My favorite number is 0

# %%
library = ['(Author', 'Topic', 'Pages', ('Twain', 'Rafting', 601), ('Simpson', 'JavaScript', 801), ('Hallan', 'Harry Potter', 1001))]

# %%
library
# Out:
# ['(Author',
#  'Topic',
#  'Pages',
#  ('Twain', 'Rafting', 601),
#  ('Simpson', 'JavaScript', 801, ('Hallan', 'Harry Potter', 1001))]

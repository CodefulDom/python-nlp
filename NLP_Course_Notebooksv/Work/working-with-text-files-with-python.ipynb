# %% [markdown]
# ## Working with text files - part 2

# %%
# %%writefile test.txt
# Hello, this is a quick text editor file
# This is how you make one as well
# Out:
# Overwriting test.txt

# %%
myfile = open('test.txt')

# %%
pwd
# Out:
# '/Users/dhallan/udemy/python-nlp/NLP_Course_Notebooksv/Work'

# %%
myfile
# Out:
# <_io.TextIOWrapper name='test.txt' mode='r' encoding='UTF-8'>

# %%
myfile.read()
# Out:
# 'Hello, this is a quick text editor file\nThis is how you make one as well\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
content = myfile.read()

# %%
print(content)
# Out:
# Hello, this is a quick text editor file
# This is how you make one as well

# %%
myfile.close()

# %%
myfile = open('test.txt')

# %%
myfile.readlines()
# Out:
# ['Hello, this is a quick text editor file\n',
#  'This is how you make one as well\n']

# %%
myfile.seek(0)
# Out:
# 0

# %%
my_lines = myfile.readlines()

# %%
my_lines
# Out:
# ['Hello, this is a quick text editor file\n',
#  'This is how you make one as well\n']

# %%
my_file = open('test.txt', 'w+')

# %%
my_file.read()
# Out:
# ''

# %%
my_file.write('My Brand new TEXT!!!!')
# Out:
# 21

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.read()
# Out:
# 'My Brand new TEXT!!!!'

# %%
my_file.close()

# %%
my_file = open('test.txt', 'a+')

# %%
my_file.write('My first line in A+ opening')
# Out:
# 27

# %%
my_file.close()

# %%
my_file = open('whoops.txt', 'a+')

# %%
my_file.write('MY FIRST LINE IN A+ OPENING')
# Out:
# 27

# %%
my_file.close()

# %%
new_file = open('whoops.txt')

# %%
new_file.read()
# Out:
# 'MY FIRST LINE IN A+ OPENING'

# %%
new_file.write('try to write something with only')
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-54-07f80d4fb385> in <module>
# ----> 1 new_file.write('try to write something with only')
#
# UnsupportedOperation: not writable

# %%
new_file.close()

# %%
my_file = open('whoops.txt', mode='a+')

# %%
my_file.write('This is an added line, because I used a+ mode')
# Out:
# 45

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.read()
# Out:
# 'MY FIRST LINE IN A+ OPENINGThis is an added line, because I used a+ mode'

# %%
my_file.write('\nThis is a real new line, on the next line')
# Out:
# 42

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.read()
# Out:
# 'MY FIRST LINE IN A+ OPENINGThis is an added line, because I used a+ mode\nThis is a real new line, on the next line'

# %%
my_file.seek(0)
# Out:
# 0

# %%
print(my_file.read())
# Out:
# MY FIRST LINE IN A+ OPENINGThis is an added line, because I used a+ mode
# This is a real new line, on the next line

# %%
my_file.close()

# %%
with open('whoops.txt', 'r') as my_new_file:
    my_variable = my_new_file.readlines()

# %%
my_variable
# Out:
# ['MY FIRST LINE IN A+ OPENINGThis is an added line, because I used a+ mode\n',
#  'This is a real new line, on the next line']
